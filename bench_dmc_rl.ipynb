# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import os
import json
import torch
import graph_utils as gu
# %matplotlib inline  
np.warnings.filterwarnings('ignore')

# %%
ROOT = 'bench_dmc_rl'
TASKS = sorted(os.listdir(ROOT))
baselines_data = torch.load('dmc_rl_baseline.pt')

# %%
 gu.plot_experiment(
        'point_mass_easy',
        'sac_off_.*_dist', 
        root=ROOT,
        train=False,
        value_name='eval_max_dist',
        baselines_data=None)

# %%
 gu.plot_experiment(
        'point_mass_easy',
        'sac_(goal|bsz_512|expbonus_0.001_v2)', 
        root=ROOT,
        train=False,
        value_name='eval_episode_reward',
        baselines_data=None, max_time=500000)

# %%
 gu.plot_experiment(
        'point_mass_maze',
        'sac_(goal|bsz_512|expbonus_0.001_v2)', 
        root=ROOT,
        train=False,
        value_name='eval_episode_reward',
        baselines_data=None, max_time=500000)

# %%
for task in TASKS:
    gu.plot_experiment(
        task,
        'sac_bsz', 
        root=ROOT,
        train=False,
        value_name='eval_episode_reward',
        baselines_data=baselines_data)
    plt.show()

# %%
gu.plot_experiment(
    'point_mass_easy',
    'sac_usepot_0', 
    root=ROOT,
    train=False,
    value_name='eval_episode_reward',
    baselines_data=None)

# %%
gu.plot_experiment(
    'point_mass_easy',
    'sac_usepot_(0_expbonus_0.001|1_expbonus_0.001|0_expbonus_0_)', 
    root=ROOT,
    train=False,
    value_name='eval_episode_reward',
    baselines_data=None)

# %%
gu.plot_experiment(
    'pendulum_swingup',
    'sac_usepot_0', 
    root=ROOT,
    train=False,
    value_name='eval_episode_reward',
    baselines_data=None)

# %%
gu.plot_experiment(
    'pendulum_swingup',
    'sac_(usepot_0_expbonus_0.01|expbonus_0.01|usepot_1_expbonus_0.1|expbonus_0_)', 
    root=ROOT,
    train=False,
    value_name='eval_episode_reward',
    baselines_data=baselines_data)

# %%
gu.plot_experiment(
    'pendulum_swingup',
    'sac_bs', 
    root=ROOT,
    train=True,
    value_name='fps',
    baselines_data=None)

# %%
gu.plot_experiment(
    'cartpole_swingup_sparse',
    'sac_use',
    root=ROOT,
    train=False,
    value_name='eval_episode_reward',
    baselines_data=baselines_data)

# %%
gu.plot_experiment(
    'cartpole_balance_sparse',
    'sac_use',
    root=ROOT,
    train=False,
    value_name='eval_episode_reward',
    baselines_data=None)

# %%
gu.plot_experiment(
    'ball_in_cup_catch',
    'sac_use',
    root=ROOT,
    train=False,
    value_name='eval_episode_reward',
    baselines_data=None)
# Out:
# bad file: bench_dmc_rl/ball_in_cup_catch/sac_usepot_0_expbonus_ca0.01_goalbonus_0_seed_1/eval.log
# bad file: bench_dmc_rl/ball_in_cup_catch/sac_usepot_0_expbonus_ca0.01_goalbonus_0_seed_2/eval.log
# bad file: bench_dmc_rl/ball_in_cup_catch/sac_usepot_0_expbonus_ca0.01_goalbonus_0_seed_3/eval.log
# bad file: bench_dmc_rl/ball_in_cup_catch/sac_usepot_0_expbonus_ca0.01_goalbonus_0_seed_4/eval.log
# bad file: bench_dmc_rl/ball_in_cup_catch/sac_usepot_0_expbonus_ca0.01_goalbonus_0_seed_5/eval.log
# bad file: bench_dmc_rl/ball_in_cup_catch/sac_usepot_0_expbonus_ca0.01_goalbonus_0_seed_6/eval.log
# bad file: bench_dmc_rl/ball_in_cup_catch/sac_usepot_0_expbonus_ca0.01_goalbonus_0_seed_7/eval.log
# bad file: bench_dmc_rl/ball_in_cup_catch/sac_usepot_0_expbonus_ca0.01_goalbonus_0_seed_8/eval.log
# bad file: bench_dmc_rl/ball_in_cup_catch/sac_usepot_0_expbonus_ca0.01_goalbonus_0_seed_9/eval.log
# ...

# %%
gu.plot_experiment(
    'pendulum_swingup',
    'sac_usepot_1', 
    root=ROOT,
    train=False,
    value_name='eval_episode_reward',
    baselines_data=None)

# %%
gu.plot_experiment(
    'point_mass_easy',
    'sac_expbonus_(0|0.01|0.001|0.0001)_(v2_seed|seed)', 
    root=ROOT,
    train=False,
    value_name='eval_episode_reward',
    baselines_data=None, max_time=200000)

# %%
gu.plot_experiment(
    'point_mass_easy',
    'sac_expbonus_.*_goal', 
    root=ROOT,
    train=False,
    value_name='eval_episode_reward',
    baselines_data=None, max_time=200000)

# %%
gu.plot_experiment(
    'point_mass_easy',
    'sac_expbonus_(0_v2_seed|0.001_seed|0.001_v2_seed|0.001_goalbonus_0.001_v2_seed|0.001_goalbonus_0.01_v2_seed)', 
    root=ROOT,
    train=False,
    value_name='eval_episode_reward',
    baselines_data=None, max_time=150000)

# %%
gu.plot_experiment(
    'point_mass_maze',
    'sac_expbonus_(0|0.01|0.001|0.0001)_(v2_seed|seed)', 
    root=ROOT,
    train=False,
    value_name='eval_episode_reward',
    baselines_data=None, max_time=150000)

# %%
gu.plot_experiment(
    'point_mass_maze',
    'sac_expbonus_.*_go', 
    root=ROOT,
    train=False,
    value_name='eval_episode_reward',
    baselines_data=None)

# %%
gu.plot_experiment(
    'point_mass_maze',
    'sac_expbonus_(0_v2_seed|0.01_seed|0.01_v2_seed|0.001_goalbonus_0.01_v2_seed)',
    root=ROOT,
    train=False,
    value_name='eval_episode_reward',
    baselines_data=None, max_time=200000)

# %%
gu.plot_experiment(
    'point_mass_maze',
    'sac_expbonus_.*_go', 
    root=ROOT,
    train=False,
    value_name='eval_episode_reward',
    baselines_data=None)

# %%
gu.plot_experiment(
    'cartpole_swingup_sparse',
    'sac', 
    root=ROOT,
    train=False,
    value_name='eval_episode_reward',
    baselines_data=baselines_data)

# %%
gu.plot_experiment(
    'reacher_hard',
    'sac', 
    root=ROOT,
    train=False,
    value_name='eval_episode_reward',
    baselines_data=None)
